# %% [markdown]
# <a href="https://colab.research.google.com/github/mike23rm/CursoGit/blob/master/PruebaGit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ChrisJavier/uide-Week_01-DataClean.git
# Out:
# Cloning into 'uide-Week_01-DataClean'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 3), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 13.91 MiB | 15.43 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %% [markdown]
# prueba de clonar git
#
#  !git clone https://github.com/ChrisJavier/uide-Week_01-DataClean.git
