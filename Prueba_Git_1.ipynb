# %% [markdown]
# <a href="https://colab.research.google.com/github/mike23rm/CursoGit/blob/master/Prueba_Git_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Validando conexion con git

# %%
#prueba para git
#dos
